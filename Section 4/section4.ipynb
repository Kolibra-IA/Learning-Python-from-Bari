# %% [markdown]
# ### Int Data Type

# %%
x = 123
y = 1234567890123

# %%
print(x)
print(y)
# Out:
# 123
# 1234567890123

# %%
import sys

sys.getsizeof(x)
# Out:
# 28

# %%
import sys 

sys.getsizeof(y)
# Out:
# 32

# %%
x= 101
id(x)
# Out:
# 140709428703272

# %%
x=205
id(x)
# Out:
# 140709428706600
